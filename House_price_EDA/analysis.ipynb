# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
data = pd.read_csv("Housing.csv")

# %% [markdown]
# ## EDA - Exploratory Data Analysis
# data exploration technique to understand the various aspects of data
# 1. understand the data
# 2. clean the data
# 3. analysis of relationship between variables

# %% [markdown]
# ### UNDERSTAND the DATA

# %%
data.head()  # default 5
# Out:
#       price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000     NaN         4          2        3      yes        no       no
# 1  12250000  8960.0         4          4        4      yes        no       no
# 2  12250000  8960.0         4          4        4      yes        no       no
# 3  12215000  7500.0         4          2        2      yes        no      yes
# 4  11410000     NaN         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no             yes        3       no        furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.tail(3)
# Out:
#        price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 542  1750000  3620.0         2          1        1      yes        no
# 543  1750000  2910.0         3          1        1       no        no
# 544  1750000  3850.0         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 542       no              no              no        0       no
# 543       no              no              no        0       no
# 544       no              no              no        0       no
#
#     furnishingstatus
# 542      unfurnished
# 543        furnished
# 544      unfurnished

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
data.shape
# Out:
# (545, 13)

# %%
data.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False   True     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False   True     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
# Null values in dataset

data.isnull().sum()
# data.isna().sum()
# Out:
# price                0
# area                12
# bedrooms             0
# bathrooms            0
# stories              0
# mainroad             0
# guestroom            0
# basement             0
# hotwaterheating      0
# airconditioning      0
# parking              0
# prefarea             0
# furnishingstatus     0
# dtype: int64

# %%
data.dtypes    # data type of each column
# Out:
# price                 int64
# area                float64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking               int64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %%
data.nunique()    # number of unique values
# Out:
# price               219
# area                277
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %%
data["bedrooms"].unique()    #unique values
# Out:
# array([4, 3, 5, 2, 6, 1])

# %%
data.duplicated()     # whether it has duplicate row or not
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Length: 545, dtype: bool

# %%
data.duplicated().sum()     # no. of duplicate rows
# Out:
# np.int64(1)

# %%
data.describe()     # describes data like count, mean, std, min, max
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    533.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5096.506567    2.966972    1.289908    1.809174
# std    1.870440e+06   2161.940425    0.739393    0.514843    0.872532
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3540.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4500.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6300.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.695413
# std      0.865429
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.info()    # shows columns and its non null values count and data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              533 non-null    float64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 55.5+ KB

# %%
# data.column.head()
# data.column.tail()

data.area.head(10)
#data["area"].tail(3)
# Out:
# 0        NaN
# 1     8960.0
# 2     8960.0
# 3     7500.0
# 4        NaN
# 5        NaN
# 6     8580.0
# 7    16200.0
# 8     8100.0
# 9     5750.0
# Name: area, dtype: float64

# %%
# data.sample()   # any random row
data.sample(5)    # random 5 rows
# Out:
#        price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 196  4970000  7686.0         3          1        1      yes       yes
# 424  3360000  3100.0         3          1        2       no        no
# 318  4060000  4340.0         3          1        1      yes        no
# 151  5565000  4400.0         4          1        2      yes        no
# 311  4123000  6060.0         2          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 196      yes             yes              no        0       no
# 424      yes              no              no        0       no
# 318       no              no              no        0       no
# 151       no              no             yes        2      yes
# 311      yes              no              no        1       no
#
#     furnishingstatus
# 196   semi-furnished
# 424   semi-furnished
# 318   semi-furnished
# 151   semi-furnished
# 311   semi-furnished

# %%
data["bedrooms"].value_counts()      # groups -- like how many rows for each unique value
# Out:
# bedrooms
# 3    299
# 2    136
# 4     96
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
newdata = data.iloc[10:20]      #extract particular range rows
print(newdata)
# Out:
#       price     area  bedrooms  bathrooms  stories mainroad guestroom  \
# 10  9800000  13200.0         3          1        2      yes        no
# 11  9681000   6000.0         4          3        2      yes       yes
# 12  9310000   6550.0         4          2        2      yes        no
# 13  9240000   3500.0         4          2        2      yes        no
# 14  9240000      NaN         3          2        2      yes        no
# 15  9100000   6000.0         4          1        2      yes        no
# 16  9100000   6600.0         4          2        2      yes       yes
# 17  8960000   8500.0         3          2        4      yes        no
# 18  8890000   4600.0         3          2        2      yes       yes
# 19  8855000   6420.0         3          2        2      yes        no
#
#    basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 10      yes              no             yes        2      yes        furnished
# ...

# %%
newdata2 = data.iloc[10:20:2]     # start : end : step
print(newdata2)
# Out:
#       price     area  bedrooms  bathrooms  stories mainroad guestroom  \
# 10  9800000  13200.0         3          1        2      yes        no
# 12  9310000   6550.0         4          2        2      yes        no
# 14  9240000      NaN         3          2        2      yes        no
# 16  9100000   6600.0         4          2        2      yes       yes
# 18  8890000   4600.0         3          2        2      yes       yes
#
#    basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 10      yes              no             yes        2      yes        furnished
# 12       no              no             yes        1      yes   semi-furnished
# 14       no              no              no        0      yes   semi-furnished
# 16      yes              no             yes        1      yes      unfurnished
# 18       no              no             yes        2       no        furnished

# %%
print(data.shape)
print(newdata.shape)
print(newdata2.shape)
# Out:
# (545, 13)
# (10, 13)
# (5, 13)

# %% [markdown]
# ### Matplotlib and Seaborn for visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.bedrooms.value_counts().plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(8,5))      # graph size width=8, height=5
plt.hist(data["price"])     # histogram -- kind of graph

plt.title("House Price Distribution")    
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))      # graph size width=8, height=5
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt=".2f", )    # annot=show numbers, fmt = floating point

plt.title("House Price Distribution")    
plt.show()

# %%
plt.figure(figsize=(8,5))      
plt.scatter(data["area"], data["price"])     

plt.title("Area vs Price")    
plt.xlabel("Area (sqft)")
plt.ylabel("Price")
plt.show()

# %%
import plotly.express  as px

# %%
fig = px.histogram(
    data,
    x="price",
    nbins=30,
    title="House Price Distribution",
)
fig.show()

# %% [markdown]
# #### scatter, line, bar, pie, heatmap, scatter_matrix, histogram, violin, box
